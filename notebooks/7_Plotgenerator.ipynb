# %%
using NBInclude
@nbinclude("6_Statistics.ipynb")
using PrettyTables
# Out:
# Estimated linear fit: f(delta_cond) = a*conc with
#  a = 0.000818±2.8e-5
#
# Estimated linear fit: f(delta_cond) = a*conc with
#  a = 0.000812±9.9e-5
#
# Estimated linear fit: f(delta_cond) = a*conc with
#  a = 0.000456±5.18e-6
#
# 958: 9.700806565484955 sd: 9.842223520028694 530: 8.798080978404498 delta_calib_958: 0.1414169545437396 delta_delta_calib_530: 1.044142541624197 delta_calib_554: 0.006539618492093169
# Trace #1 Sensor #2:202.0   Trace #2 Sensor #2:53.0   Trace #3 Sensor #2:45.0   Trace #3 Sensor #1:20.0   Trace #4 Sensor #2:52.0   Trace #4 Sensor #1:40.0   Trace #5 Sensor #2:116.0   Trace #5 Sensor #1:115.0   Trace #6 Sensor #2:46.0   Trace #6 Sensor #1:35.0   Trace #7 Sensor #2:45.0   Trace #7 Sensor #1:30.0   Trace #8 Sensor #2:52.0   Trace #8 Sensor #1:20.0   Trace #9 Sensor #2:200.0   Trace #9 Sensor #1:155.0   Trace #10 Sensor #2:45.0   Trace #10 Sensor #1:50.0
# [ Info: Unsafe comparisons using the function `pmean` has been enabled globally. Use `@unsafe` to enable in a local expression only or `unsafe_comparisons(false)` to turn off unsafe comparisons
# Estimated linear fit sensor 554: Q(s) = a + b*stage with
#  a = 0.0524 ± 0.028, b = 2.89 ± 0.25
#
# [0.1971125033035099, 0.2398566419375575, 0.005514134292297797]Estimated linear fit sensor 530: Q(s) = a + b*stage with
#  a = -0.031 ± 0.01, b = 0.776 ± 0.082
#
# [0.19400186884132273, 0.296603295956511, 0.04695599728168976]Estimated linear fit sensor 958: Q(s) = a + b*stage with
#  a = 0.0563 ± 0.012, b = 1.36 ± 0.11
#
# [0.1284159351757479, 0.12688892192396375, -0.026564696832406476]Estimated linear fit sensor 554: Q(s) = a + b*stage with
#  a = 0.0482 ± 0.022, b = 2.26 ± 0.2
#
# Estimated linear fit sensor 958: Q(s) = a + b*stage with
#  a = 0.0487 ± 0.0096, b = 1.07 ± 0.088
#
# Estimated linear fit sensor 530: Q(s) = a + b*stage with
#  a = 0.0334 ± 0.0039, b = 0.36 ± 0.042
#
# 0.2280560.007919840.195725Estimated linear fit sensor 1.0: v(s) = a + b*stage with
#  a = 0.415, b = 4.72
#
# 0.3002190.195124Estimated linear fit sensor 2.0: v(s) = a + b*stage with
#  a = 0.0622, b = 2.73
#
# 0.1271990.130708Estimated linear fit sensor 4.0: v(s) = a + b*stage with
#  a = 1.0, b = 1.25e-10
# Mean depth1 = 0.25857054311848826,  Mean depth2 = 0.2785690884493462,  Mean depth3 = 0.2771758393195831,
# WARNING: using Plots.scatter! in module Main conflicts with an existing identifier.
# WARNING: using Plots.xlims! in module Main conflicts with an existing identifier.
# WARNING: using Plots.ylims! in module Main conflicts with an existing identifier.
# ┌ Warning: Assignment to `d` in soft scope is ambiguous because a global variable by the same name exists: `d` will be treated as a new local. Disambiguate by using `local d` to suppress this warning or `global d` to assign to the existing global variable.
# └ @ C:\Users\herol\julia\GlacierHydroFieldcourse.jl\notebooks\6_Statistics.ipynb:In[133]:14
# ┌ Warning: Assignment to `w` in soft scope is ambiguous because a global variable by the same name exists: `w` will be treated as a new local. Disambiguate by using `local w` to suppress this warning or `global w` to assign to the existing global variable.
# └ @ C:\Users\herol\julia\GlacierHydroFieldcourse.jl\notebooks\6_Statistics.ipynb:In[133]:15
# ┌ Warning: Assignment to `j` in soft scope is ambiguous because a global variable by the same name exists: `j` will be treated as a new local. Disambiguate by using `local j` to suppress this warning or `global j` to assign to the existing global variable.
# └ @ C:\Users\herol\julia\GlacierHydroFieldcourse.jl\notebooks\6_Statistics.ipynb:In[32]:37
# LoadError: UndefVarError: `j` not defined
# in expression starting at C:\Users\herol\julia\GlacierHydroFieldcourse.jl\notebooks\6_Statistics.ipynb:In[32]:17
#
# Stacktrace:
#   [1] top-level scope
#     @ C:\Users\herol\julia\GlacierHydroFieldcourse.jl\notebooks\6_Statistics.ipynb:In[32]:18
#   [2] eval
#     @ .\boot.jl:385 [inlined]
#   [3] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
#     @ Base .\loading.jl:2076
#   [4] include_string
#     @ .\loading.jl:2086 [inlined]
#   [5] my_include_string(m::Module, s::String, path::String, prev::Nothing, softscope::Bool)
#     @ NBInclude C:\Users\herol\.julia\packages\NBInclude\pwlhS\src\NBInclude.jl:30
#   [6] #2
#     @ C:\Users\herol\.julia\packages\NBInclude\pwlhS\src\NBInclude.jl:93 [inlined]
#   [7] task_local_storage(body::NBInclude.var"#2#3"{Bool, Module, String, Nothing, String, String}, key::Symbol, val::Bool)
#     @ Base .\task.jl:304
#   [8] nbinclude(m::Module, path::String; renumber::Bool, counters::UnitRange{Int64}, regex::Regex, anshook::typeof(identity), softscope::Bool)
#     @ NBInclude C:\Users\herol\.julia\packages\NBInclude\pwlhS\src\NBInclude.jl:92
#   [9] nbinclude(m::Module, path::String)
#     @ NBInclude C:\Users\herol\.julia\packages\NBInclude\pwlhS\src\NBInclude.jl:57
#  [10] top-level scope
#     @ In[1]:2

# %%
polyg_results = polyg[:, ["Stream", "Section", "FlowLength", "Sinu","W_avg_measured", "W_avg_A", "DeltaH",
    "Depth_avg", "AR_measured", "AR_A", "Grad_straight", "Grad_flow", 
    "Q_mean_sd", "Q_max_sd", "Q_max_meas", "v_Qmax", "f_Qmax"]]
# Out:
# 15×17 DataFrame
#  Row │ Stream  Section  FlowLength    Sinu          W_avg_measured  W_avg_A    ⋯
#      │ Int64   Int64    Particles…    Particles…    Particles…      Particles… ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │      1        0  134.0 ± 2.7   1.08 ± 0.022   1.67 ± 0.017   1.61 ± 0.1 ⋯
#    2 │      1        1   65.2 ± 1.4   1.02 ± 0.023   1.46 ± 0.022   1.42 ± 0.1
#    3 │      1        2   69.3 ± 1.4   1.1 ± 0.024    1.94 ± 0.025   1.8 ± 0.18
#    4 │      2        0  324.0 ± 6.4   1.12 ± 0.022   0.985 ± 0.019  0.944 ± 0.
#    5 │      2        1  225.0 ± 4.5   1.08 ± 0.022   0.967 ± 0.028  0.854 ± 0. ⋯
#    6 │      2        2   99.2 ± 2.0   1.19 ± 0.025   0.999 ± 0.026  1.14 ± 0.1
#    7 │      3        0  127.0 ± 2.6   1.05 ± 0.022   0.906 ± 0.018  1.02 ± 0.1
#    8 │      3        1   56.3 ± 1.2   1.07 ± 0.024   0.875 ± 0.025  1.03 ± 0.1
#    9 │      3        2   70.5 ± 1.5   1.04 ± 0.023   0.937 ± 0.025  1.01 ± 0.1 ⋯
#   10 │      4        0  121.0 ± 2.4   1.23 ± 0.026   1.22 ± 0.02    1.16 ± 0.1
#   11 │      4        1   28.3 ± 0.6   1.15 ± 0.034   1.35 ± 0.036   1.21 ± 0.1
#   12 │      4        2   92.8 ± 1.9   1.24 ± 0.026   1.15 ± 0.025   1.15 ± 0.1
#   13 │      5        0   84.2 ± 1.7   1.1 ± 0.024    0.725 ± 0.02   0.901 ± 0. ⋯
#   14 │      5        1   57.3 ± 1.2   1.1 ± 0.025    0.737 ± 0.025  0.979 ± 0.
#   15 │      5        2   27.1 ± 0.55  1.01 ± 0.027   0.702 ± 0.035  0.733 ± 0.
#                                                               12 columns omitted

# %%
# Save LaTeX table code to a .tex file
open("../data/products/polyg.tex", "w") do io
    pretty_table(io, polyg_results, backend = Val(:latex))
end
# Out:
# UndefVarError: `pretty_table` not defined
#
# Stacktrace:
#  [1] (::var"#189#190")(io::IOStream)
#    @ Main .\In[100]:3
#  [2] open(::var"#189#190", ::String, ::Vararg{String}; kwargs::@Kwargs{})
#    @ Base .\io.jl:396
#  [3] open(::Function, ::String, ::String)
#    @ Base .\io.jl:393
#  [4] top-level scope
#    @ In[100]:2

# %%
#color palette
colors = [ "#ff7f00", "#4daf4a" , "#ffff33","#984ea3", "#377eb8"];
#colors = [Makie.wong_colors()[1], Makie.wong_colors()[2], Makie.wong_colors()[3], Makie.wong_colors()[4], Makie.wong_colors()[6]]
#colors = ["#c44601", "#f57600", "#8babf1", "#0073e6", "#054fb9"]
#colors = ["#1b9e77", "#66c2a5", "#e78ac3", "#ffd92f", "#a6761d"];

# %%
p = Plots.plot() #title = "Normalised values of different Stream properties"
zeros = [0 for _ in 1:15]
ones = [1 for _ in 1:15]
twos = [2 for _ in 1:15]
threes = [3 for _ in 1:15]
fours = [4 for _ in 1:15]
fives = [5 for _ in 1:15]
sixes = [6 for _ in 1:15]
#categories = ["Q_max", "Width", "Depth", "f", "v", "Gradient"]
categories = [L"AR_s", L"Q_{max}", L"W_s^{insitu}", L"D_s", L"f_s(Q_{max})", L"v_s(Q_{max})", L"\nabla_s^S"]
Plots.scatter!(zeros, mean_object(polyg.AR_measured)/maximum(mean_object(polyg.AR_measured)), c = colors[polyg.Stream], label = false)
Plots.scatter!(ones, mean_object(polyg.Q_max_meas)/maximum(mean_object(polyg.Q_max_meas)), c = colors[polyg.Stream], label = false)
Plots.scatter!(twos, mean_object(polyg.W_avg_measured)/maximum(mean_object(polyg.W_avg_measured)), c = colors[polyg.Stream], label = false)
Plots.scatter!(threes, mean_object(polyg.Depth_avg)/maximum(mean_object(polyg.Depth_avg)),c = colors[polyg.Stream], label = false)
Plots.scatter!(fours, mean_object(polyg.f_Qmax)/maximum(mean_object(polyg.f_Qmax)),c = colors[polyg.Stream], label = false)
Plots.scatter!(fives, mean_object(polyg.v_Qmax)/maximum(mean_object(polyg.v_Qmax)),c = colors[polyg.Stream], label = false)
Plots.scatter!(sixes, mean_object(polyg.Grad_straight)/maximum(mean_object(polyg.Grad_straight)),c = colors[polyg.Stream], label = false)
Plots.xlims!(-1, length(categories))
Plots.ylims!(0,1.05)
Plots.xticks!(0:length(categories)-1, categories)

Plots.plot!(1,1, label="Stream 1", marker=:circle, color=colors[1], linealpha = 0)
Plots.plot!(1,1, label="Stream 2", marker=:circle, color=colors[2], linealpha = 0)
Plots.plot!(1,1, label="Stream 3", marker=:circle, color=colors[3], linealpha = 0)
Plots.plot!(1,1, label="Stream 4", marker=:circle, color=colors[4], linealpha = 0)
Plots.plot!(1,1, label="Stream 5", marker=:circle, color=colors[5], linealpha = 0)
display(p)
savefig("../data/products/plots/final/Normalised-values_final.png")
# Out:
# "C:\\Users\\herol\\julia\\GlacierHydroFieldcourse.jl\\data\\products\\plots\\final\\Normalised-values_final.png"

# %%
#legend is always the same
function legend()
Plots.plot!(1,1, label="Whole stream", marker=:circle, color=:white, markerstrokecolor=:black)
Plots.plot!(1,1, label="Section 1", marker=:diamond, color=:white, markerstrokecolor=:black)
Plots.plot!(1,1, label="Section 2", marker=:rect, color=:white, markerstrokecolor=:black)
Plots.plot!(1,1, label="Stream 1", marker=:circle, color=colors[1], linealpha = 0, markerstrokecolor=colors[1])
Plots.plot!(1,1, label="Stream 2", marker=:circle, color=colors[2], linealpha = 0, markerstrokecolor=colors[2])
Plots.plot!(1,1, label="Stream 3", marker=:circle, color=colors[3], linealpha = 0, markerstrokecolor=colors[3])
Plots.plot!(1,1, label="Stream 4", marker=:circle, color=colors[4], linealpha = 0, markerstrokecolor=colors[4])
Plots.plot!(1,1, label="Stream 5", marker=:circle, color=colors[5], linealpha = 0, markerstrokecolor=colors[5])
end
# Out:
# legend (generic function with 1 method)

# %%
p1 = Plots.scatter(polyg.Sinu, polyg.AR_measured, c=colors[polyg.Stream], marker = symbols[polyg.Section.+1], xlabel = L"Sinu_s \enspace [-]", ylabel = L"AR_s \enspace [-]", label = false)
legend()
savefig("../data/products/plots/final/AR-Sinu_final.png")
p1

# %%
p2 = Plots.scatter(polyg.Depth_avg, polyg.AR_measured, c=colors[polyg.Stream], marker = symbols[polyg.Section.+1], xlabel = L"D_s \enspace [m]", ylabel = L"AR_s \enspace [-]", label = false)
legend()
savefig("../data/products/plots/final/AR-Depth_final.png")
p2

# %%
p3 = Plots.scatter(polyg.W_avg_measured, polyg.AR_measured, c=colors[polyg.Stream], marker = symbols[polyg.Section.+1], xlabel = L"W_s^{insitu} \enspace [m]", ylabel = L"AR_s \enspace [-]", label = false)
legend()
savefig("../data/products/plots/final/AR-Width_final.png")
p3

# %%
p4 = Plots.scatter(polyg.W_avg_measured, polyg.Depth_avg, c=colors[polyg.Stream], marker = symbols[polyg.Section.+1], xlabel = L"W_s^{insitu} \enspace [m]", ylabel = L"D_s \enspace [m]", label = false)
legend()
savefig("../data/products/plots/final/Depth-Width_final.png")
p4

# %%
#plot discharge time series and measured discharges

Makie.inline!(false)
fig = Figure()

ax = Axis(fig[1,1], xlabel = L"t", ylabel = L"Q \enspace [m^3/s]")
lines!(ax, sq1[:t], s1q2_smoothed, label = L"\text{Stream 1 } Q_2", color = colors[1])
lines!(ax, sq1[:t], s1q1_smoothed, label = L"\text{Stream 1 } Q_1", color = colors[1], linestyle = (:dash, :loose))
lines!(ax, sq2[:t], s2q2_smoothed, label = L"\text{Stream 2 } Q_2", color = colors[2])
lines!(ax, sq2[:t], s2q1_smoothed, label = L"\text{Stream 2 } Q_1", color = colors[2], linestyle = (:dash, :loose))
lines!(ax, sq4[:t], s4q2_smoothed, label = L"\text{Stream 4 } Q_2", color = colors[4])
lines!(ax, sq4[:t], s4q1_smoothed, label = L"\text{Stream 4 } Q_1", color = colors[4], linestyle = (:dash, :loose))


#band!(ax, x, y_mean .- y_std, y_mean .+ y_std, color=:blue, transparency=true, alpha=0.2, label="Uncertainty")

for i in 1:length(traces.loc)
    if traces.loc[i] != 3 && traces.loc[i] != 5 #&& traces.loc[i] != 4
        scatter!(traces.t_inj[i], mean_object(traces.Q2[i]), color = colors[traces.loc[i]], strokecolor = :black, strokewidth = 1, marker = :rect)
        scatter!(traces.t_inj[i], mean_object(traces.Q1[i]), color = colors[traces.loc[i]], strokecolor = :black, strokewidth = 1, marker = :diamond)
    end
end

#scatter!(sd_rel1_values[554][1, :])


xmin = DateTime(2024, 8, 8, 17, 00, 0)
xmax = DateTime(2024, 8, 11, 15, 00, 0)
xlims!(ax, xmin, xmax)

#ylims!(ax, 9.5, 10)

axislegend(ax, position = :rt, margin = (0,27,0,10))
fig
save("../data/products/plots/final/Discharge-Time_final.png", fig)

# %%
#plot stage raw
#in NB 5 because i modify the values afterwards

# %%
s1s_smoothed = moving_average(sq1[:s])
s2s_smoothed = moving_average(sq2[:s])
s4s_smoothed = moving_average(sq4[:s]);

# %%
Makie.inline!(false)
fig = Figure()

ax = Axis(fig[1,1], xlabel = L"t", ylabel = L"\text{Stage } [m]")
lines!(ax, sq1[:t], s1s_smoothed, label = "Stream 1", color = colors[1])
lines!(ax, sq2[:t], s2s_smoothed, label = "Stream 2", color = colors[2])
lines!(ax, sq4[:t], s4s_smoothed, label = "Stream 4", color = colors[4])

xlims!(ax, xmin, xmax)
#ylims!(ax, 9.5, 10)

axislegend(ax, position = :lt)
display(fig)
#save("../data/products/plots/final/Stage-Time-correctedsmoothed_final.png", fig)
# Out:
# GLMakie.Screen(...)

# %%
"""
# Combine subplots
p = Plots.plot(p1, p2, p3, p4, layout=(2, 2))
p_leg = Plots.plot(p, legend_position = (3.1,-1), right_margin=20Plots.mm, bottom_margin = 10Plots.mm)

#empty_plot = Plots.plot(legend=:outerbottomright, framestyle=:none)

Plots.plot!(1,1, label="Section 0", marker=:circle, color=:white, markerstrokecolor=:black)
Plots.plot!(1,1, label="Section 1", marker=:diamond, color=:white, markerstrokecolor=:black)
Plots.plot!(2,2, label="Section 2", marker=:rect, color=:white, markerstrokecolor=:black)
Plots.plot!(2,2, label="Stream 1", marker=:circle, color=:red, linealpha = 0, markerstrokecolor=:red)
Plots.plot!(2,2, label="Stream 2", marker=:circle, color=:blue, linealpha = 0, markerstrokecolor=:blue)
Plots.plot!(2,2, label="Stream 3", marker=:circle, color=:green, linealpha = 0, markerstrokecolor=:green)
Plots.plot!(2,2, label="Stream 4", marker=:circle, color=:darkorange, linealpha = 0, markerstrokecolor=:darkorange)
Plots.plot!(2,2, label="Stream 5", marker=:circle, color=:pink, linealpha = 0, markerstrokecolor=:pink)

#p_leg = Plots.plot(p, empty_plot, layout=(1, 2))
display(p_leg)
"""
# Out:
# "# Combine subplots\np = Plots.plot(p1, p2, p3, p4, layout=(2, 2))\np_leg = Plots.plot(p, legend_position = (3.1,-1), right_margin=20Plots.mm, bottom_margin = 10Plots.mm)\n\n#empty_plot = Plots.plot(legend=:outerbottomright, framestyle=:none)\n\nPlots.plot!(1,1, label=\"Section " ⋯ 571 bytes ⋯ " label=\"Stream 4\", marker=:circle, color=:darkorange, linealpha = 0, markerstrokecolor=:darkorange)\nPlots.plot!(2,2, label=\"Stream 5\", marker=:circle, color=:pink, linealpha = 0, markerstrokecolor=:pink)\n\n#p_leg = Plots.plot(p, empty_plot, layout=(1, 2))\ndisplay(p_leg)\n"

# %%
#CSV.write("../data/products/polyg.csv", polyg)

# %%
Plots.plot(d_sd[:t], d_sd[:temp])

# %%
met = CSV.read("../data/raw/KonkiMetData 069710_19-07-24_12-08-24.csv", DataFrame, header = 2)
#help(CSV.read)
Plots.plot(met.TL[3031:end])
#maximum(met.TL[3031:end])
